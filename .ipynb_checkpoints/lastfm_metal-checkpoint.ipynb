# %%
import metallum
import pylast
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %%
# %%bash
# Rscript get_scrobbles.R
# Out:
#   |======================================================================| 100%
# Loading required package: curl
# Loading required package: data.table
# Loading required package: xml2

# %%
x = pd.read_csv("scrobbles.csv")
artist_counts = pd.DataFrame(x.artist.value_counts())

# %%
N = 25
artists_topN = [metallum.band_search(i) for i in artist_counts.index[0:N]]
artists_topN = [i[0].get() for i in artists_topN if len(i) > 0]

# %%
from PIL import Image
import requests
from io import BytesIO

response = requests.get(artists_topN[16].logo)
img = Image.open(BytesIO(response.content))
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x149 at 0x7FD0A547C8D0>
